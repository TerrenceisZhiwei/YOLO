# %% [markdown]
# # Step 1: Prepare Google Drive
# - Create 'Root Directory Folder' in your Google Drive
# - Create file structure in Google Drive
#   - `/content/drive/MyDrive/Scraper/src_1/`

# %%
#@markdown ## Mount Google Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Setup Your Directory (Save)
dir = '/content/drive/MyDrive/YOLO/scrape/src_1' # First run
# dir = '/content/drive/MyDrive/Scraper/src_2' # Second run & so on...

# %% [markdown]
# # Step 2: Run the Web Scraper

# %%
# !pip install bing-image-downloader

from bing_image_downloader import downloader
import os

# Where to save images
base_dir = "/content/drive/MyDrive/YOLO/scrape/YOLO_Bike_Scrape"

search_terms = [
    # Architectural details
    #"bike",
    "bicycle"
]

# Number of images per search
number_images = 50  # Increase as needed

# Loop & download
for term in search_terms:
    print(f"\n Downloading: {term} ...")
    downloader.download(
        term,
        limit=number_images,
        output_dir=base_dir,
        adult_filter_off=True,
        force_replace=False,
        timeout=60
    )

print("\n All downloads complete!")
# Out:
# ...
#
#  Downloading: bicycle ...
# [%] Downloading Images to /content/drive/MyDrive/YOLO/scrape/YOLO_Bike_Scrape/bicycle
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 47 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://wallpaperaccess.com/full/333323.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://wallpapers.com/images/hd/bicycle-pictures-o6e198w7pnp7vzrs.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://cdn.pixabay.com/photo/2021/06/22/06/56/bicycle-6355326_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://cdn.pixabay.com/photo/2016/11/18/12/49/bicycle-1834265_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/giant-trance-0003-1531948051.jpg?crop=0.668xw:1.00xh;0.154xw
# [%] File Downloaded !
#
# ...

# %%
from bing_image_downloader import downloader
import os

# Where to save images
base_dir = "/content/drive/MyDrive/YOLO/scrape/Building_Details"

search_terms = [
    # Architectural details
    "modern facade panel detail",
    "brick wall section construction detail",
    "roof truss joint detail drawing",
    "window mullion detail rendering",
    "curtain wall connection detail",
    "staircase railing architectural detail",
    "floor slab edge detail",
    "architectural exploded axon detail",

    # Products & stock materials
    "concrete wall panel texture",
    "weathered steel cladding material",
    "wood siding architectural rendering",
    "glass curtain wall panel stock",
    "perforated metal facade product",
    "stone tile wall rendering",
    "parametric facade system material",
    "aluminum window frame detail",

    # Rendering styles
    "architectural clay render exterior",
    "photorealistic architectural render",
    "daylight study rendering architecture",
    "architectural night render",
    "axonometric exploded render",
    "material sample board rendering",

    # Construction & assembly
    "prefabricated wall panel construction",
    "architectural section cut detail",
    "cross laminated timber joint detail",
    "architectural fabrication detail drawing",
    "structural steel joint connection render",

    # Gallery & exhibition details
    "architectural model exhibition view",
    "gallery installation architectural model",
    "architectural rendering in gallery space",
    "architectural drawing wall display",
    "exhibition detail architectural panel",
]

# Number of images per search
number_images = 50  # Increase as needed

# Loop & download
for term in search_terms:
    print(f"\n Downloading: {term} ...")
    downloader.download(
        term,
        limit=number_images,
        output_dir=base_dir,
        adult_filter_off=True,
        force_replace=False,
        timeout=60
    )

print("\n All downloads complete!")
